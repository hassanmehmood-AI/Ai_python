# %%
#textual data can be stored in different types.
# csv, Json, tsv,

# %%
! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.0 MB 4.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/11.0 MB 6.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.7/11.0 MB 8.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.0 MB 8.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 8.1 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv('bestsellers.csv')

# %%
data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
data.shape
# Out:
# (550, 7)

# %%
data.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
data.head()# by default 5 rows
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
data.head(10)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
# 8      A Higher Loyalty: Truth, Lies, and Leadership
# 9                          A Man Called Ove: A Novel
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# ...

# %%
data.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
data.tail(10)
# Out:
#                                                   Name         Author  \
# 540                                             Wonder  R. J. Palacio
# 541                                             Wonder  R. J. Palacio
# 542                                             Wonder  R. J. Palacio
# 543                                             Wonder  R. J. Palacio
# 544                                             Wonder  R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)    Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 540          4.8    21625      9  2013      Fiction
# 541          4.8    21625      9  2014      Fiction
# ...

# %%
data.describe()# it can see the numerical data only
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
data.info()#it can show numeric or string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
data.sample(10)# randomly pic the row&column
# Out:
#                                                   Name              Author  \
# 190  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 470                           The Time Traveler's Wife  Audrey Niffenegger
# 444  The Official SAT Study Guide, 2016 Edition (Of...   The College Board
# 66                      Dear Zoo: A Lift-the-Flap Book        Rod Campbell
# 269  Proof of Heaven: A Neurosurgeon's Journey into...      Eben Alexander
# 547  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 158                         Harry Potter Coloring Book          Scholastic
# 9                            A Man Called Ove: A Novel     Fredrik Backman
# 268  Pokémon Deluxe Essential Handbook: The Need-to...          Scholastic
# 19                                  Alexander Hamilton         Ron Chernow
#
#      User Rating  Reviews  Price  Year        Genre
# 190          4.9    19576      8  2014  Non Fiction
# ...

# %%
# datafram is 2D size mutable, potentialy hetrogenous tablubar data structure with labeled axes.

# %%
data['Name']
# Out:
# 0                          10-Day Green Smoothie Cleanse
# 1                                      11/22/63: A Novel
# 2                12 Rules for Life: An Antidote to Chaos
# 3                                 1984 (Signet Classics)
# 4      5,000 Awesome Facts (About Everything!) (Natio...
#                              ...
# 545         Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546    You Are a Badass: How to Stop Doubting Your Gr...
# 547    You Are a Badass: How to Stop Doubting Your Gr...
# 548    You Are a Badass: How to Stop Doubting Your Gr...
# 549    You Are a Badass: How to Stop Doubting Your Gr...
# Name: Name, Length: 550, dtype: object

# %%
tab=pd.read_csv("movie_titles.tsv")

# %%
tab
# Out:
#     m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0    m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1    m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2    m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3    m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4    m5\tthe fifth element\t1997\t7.50\t133756\t['a...
# ..                                                 ...
# 611  m612\twatchmen\t2009\t7.80\t135229\t['action' ...
# 612  m613\txxx\t2002\t5.60\t53505\t['action' 'adven...
# 613  m614\tx-men\t2000\t7.40\t122149\t['action' 'sc...
# 614  m615\tyoung frankenstein\t1974\t8.00\t57618\t[...
# 615  m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
#
# [616 rows x 1 columns]

# %%
tab=pd.read_csv("movie_titles.tsv", sep='\t')

# %%
tab
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %%
pd.options.display.max_rows=9999

# %%
(18+25.8+21+30+25.8+35+25)/7
# Out:
# 25.8

# %%
net=pd.read_csv("netflix_titles.csv", sep='|', index_col=0)
net.head()

# %%
net.columns

# %%
net.shape

# %%
net['type'].unique()

# %%
net['country'].unique()

# %%
net['director'].nunique()

# %%
import pandas as pd

# %%
best=pd.read_csv("bestsellers.csv")

# %%
best['User Rating'].value_counts()
# Out:
# User Rating
# 4.8    127
# 4.7    108
# 4.6    105
# 4.5     60
# 4.9     52
# 4.4     38
# 4.3     25
# 4.0     14
# 4.2      8
# 4.1      6
# 3.9      3
# 3.8      2
# 3.6      1
# 3.3      1
# Name: count, dtype: int64

# %%
best.sum()
# Out:
# Name           10-Day Green Smoothie Cleanse11/22/63: A Novel...
# Author         JJ SmithStephen KingJordan B. PetersonGeorge O...
# User Rating                                               2540.1
# Reviews                                                  6574305
# Price                                                       7205
# Year                                                     1107700
# Genre          Non FictionFictionNon FictionFictionNon Fictio...
# dtype: object

# %%
best.sum(numeric_only=True)
# Out:
# User Rating       2540.1
# Reviews        6574305.0
# Price             7205.0
# Year           1107700.0
# dtype: float64

# %%
best.min()
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                      Abraham Verghese
# User Rating                              3.3
# Reviews                                   37
# Price                                      0
# Year                                    2009
# Genre                                Fiction
# dtype: object

# %%
best.min(numeric_only=True)
# Out:
# User Rating       3.3
# Reviews          37.0
# Price             0.0
# Year           2009.0
# dtype: float64

# %%
best.max()
# Out:
# Name           You Are a Badass: How to Stop Doubting Your Gr...
# Author                                              Zhi Gang Sha
# User Rating                                                  4.9
# Reviews                                                    87841
# Price                                                        105
# Year                                                        2019
# Genre                                                Non Fiction
# dtype: object

# %%
best.max(numeric_only=True)
# Out:
# User Rating        4.9
# Reviews        87841.0
# Price            105.0
# Year            2019.0
# dtype: float64

# %%
best.mean()# Average value
best.median()# Central value
best.mode()# Code frequent value

# %%
net.to_csv("clean_net.csv")

# %%
import pandas as pd

# %%
bs=pd.read_csv("bestsellers.csv")

# %%
bs.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
